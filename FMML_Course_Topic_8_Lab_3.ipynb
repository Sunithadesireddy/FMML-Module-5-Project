# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunithadesireddy/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 12:01:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   193MB/s    in 0.4s
#
# 2024-03-31 12:01:38 (193 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4394   1703.07886v2  Dictionary learning and component analysis are...  stat
# 37174  1609.05787v1  Since sequential information plays an importan...    cs
# 13509   1406.2614v4  This paper has been withdrawn by the author du...    cs
# 3228    1408.0972v1  A novel framework for consensus clustering is ...  stat
# 22795  1706.09985v1  A rising topic in computational journalism is ...  stat
# ...             ...                                                ...   ...
# 1094   1707.04319v1  We consider the problem of deep neural net com...    cs
# 6234   1610.01642v1  We introduce a machine learning approach for e...  stat
# 3559   1712.02609v1  This work proposes a novel solution to the pro...  stat
# 39843  1706.03497v1  We present a filter based approach for inbetwe...    cs
# 33139  1802.07980v1  Motivated by the increasing availability of ve...    cs
#
#                                                    title  year  \
# 4394   Robust Kronecker-Decomposable Component Analys...  2017
# 37174            Context-aware Sequential Recommendation  2016
# 13509  Application and Verification of Algorithm Lear...  2014
# 3228   A Flexible Iterative Framework for Consensus C...  2014
# 22795  Towards Bursting Filter Bubble via Contextual ...  2017
# ...                                                  ...   ...
# 1094   Model compression as constrained optimization,...  2017
# 6234   Learning Protein Dynamics with Metastable Swit...  2016
# 3559   Solving internal covariate shift in deep learn...  2017
# 39843           A filter based approach for inbetweening  2017
# 33139  Learning to Route with Sparse Trajectory Sets-...  2018
#
#                                                 keywords
# 4394   [dictionary, component, intersection, processi...
# 37174  [sequential, information, important, behaviors...
# 13509  [withdrawn, performance, following, algorithm,...
# 3228   [framework, consensus, clustering, presented, ...
# 22795  [computational, journalism, diversity, subscri...
# ...                                                  ...
# 1094   [compression, quantization, reference, quantiz...
# 6234   [introduce, extracting, representations, evolu...
# 3559   [covariate, constraints, activations, operatin...
# 39843  [inbetweening, convolutional, intermediate, an...
# 33139  [motivated, increasing, availability, trajecto...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4394     [dictionary, component, intersection, processi...
# 37174    [sequential, information, important, behaviors...
# 13509    [withdrawn, performance, following, algorithm,...
# 3228     [framework, consensus, clustering, presented, ...
# 22795    [computational, journalism, diversity, subscri...
#                                ...
# 26628    [architectures, measuring, similarity, photogr...
# 26129    [different, approaches, convolutional, recurre...
# 7369     [maximizing, fmathcalx, framework, particular,...
# 22011    [multivariate, correlated, likelihood, multiva...
# 24860    [efficient, detection, classifier, efficient, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8822 words.
# Out of those 4579 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f02142fb-43f4-4fa2-9c41-22a059e7c0f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f02142fb-43f4-4fa2-9c41-22a059e7c0f9")) {                    Plotly.newPlot(                        "f02142fb-43f4-4fa2-9c41-22a059e7c0f9",                        [{"x":["component","decomposition","separability","efficient","restricted","factorization","subtraction","magnitude","performing","kronecker","relaxation","demonstrated","applications","combining","denoising","computations","algorithm","leverages","corruptions","processing","corruption","intersection","sensitive","effectiveness","introduce","significantly","comparison","dictionary","decomposable","expensive","additionally","structure","background","principal","statistical","difficulty","significant","conventional","information","components","movielens","transition","behaviors","important","recommendation","contextual","successfully","independently","experimental","historical","recurrent","sequences","situations","assumption","sequential","improvements","intervals","integrating","verification","application","withdrawn","selection","performance","following","classification","considering","technique","techniques","consensus","probability","determining","individual","iterative","presented","similarity","associated","reduction","determine","considered","framework","uncoupled","algorithms","eigenvalues","clustering","dimension","dimensional","encourages","evaluated","coefficients","estimation","experiences","successful","distributed","viewpoints","computational","exploitation","recommend","variability","diversity","uncertainty","conditional","classifier","predicted","estimator","targeting","preference","posterior","outperformed","providers","efficiently","efficiency","forecasts","identifying","efficiencies","personalized","uncertainties","exploration","exceptional","diversified","categorical","frequencies","normalized","qualitative","coordinates","frequency","modification","comparing","interpretable","according","assignment","relations","empirical","theoretical","character","proportions","displaying","distributions","languages","translations","different","applicable","categories","linguistically","graphical","variation","meaningful","incorporate","reservoir","robustness","challenging","correlation","balancing","mahalanobis","regularized","computationally","adaptability","unbounded","optimization","sacrificing","obtaining","foreground","dimensions","proximity","especially","furthermore","representation","exhibiting","appearance","demonstrate","representations","implementation","convergence","initialization","approaches","pollination","preserving","observers","evaluation","perception","investigate","quantitative","enhancement","standpoint","questions","answering","embeddings","descriptions","exploring","segmentation","generation","available","published","intermediate","detection","extensions","systematically","projection","decidability","expressed","knowledge"],"y":[109,62,7,405,37,30,9,49,89,3,13,96,407,105,40,32,778,36,1,273,8,12,58,237,364,261,131,45,7,68,69,334,79,40,160,56,244,106,663,94,5,33,23,360,32,54,81,44,380,22,162,91,63,73,82,108,18,35,45,263,5,162,880,85,506,58,236,337,14,181,30,114,73,179,151,114,118,72,122,541,1,541,10,149,45,187,21,140,37,193,12,71,105,14,305,12,9,31,67,86,94,148,52,25,5,22,40,20,4,164,145,1,62,3,14,8,57,1,2,16,14,19,54,9,53,24,61,33,105,23,96,134,167,57,5,3,102,116,18,777,44,79,12,41,59,50,65,5,92,266,57,14,7,43,93,4,13,301,10,30,27,43,14,111,172,362,7,72,558,211,137,111,16,425,2,45,9,245,51,159,75,30,2,69,53,60,29,38,206,144,306,42,33,348,42,23,54,6,42,357],"type":"bar"},{"x":["component","decomposition","separability","efficient","restricted","fa ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4579,), (4579, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Computational</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Politeness</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Social</span> <span style=''>Factors</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style='background-color:rgba(0, 255, 0, 0.9302325581395349);'>linguistic</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>politeness</span> <span style=''>Our</span> <span style=''>starting</span> <span style=''>point</span> <span style=''>is</span> <span style=''>a</span> <span style=''>new</span> <span style=''>corpus</span> <span style=''>of</span> <span style=''>requests</span> <span style='background-color:rgba(0, 255, 0, 0.9036144578313253);'>annotated</span> <span style=''>for</span> <span style=''>politeness</span> <span style=''>which</span> <span style=''>we</span> <span style=''>use</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>politeness</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>to</span> <span style=''>uncover</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>between</span> <span style=''>politeness</span> <span style=''>markers</span> <span style=''>and</span> <span style=''>context</span> <span style=''>These</span> <span style=''>findings</span> <span style=''>guide</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>with</span> <span style=''>domain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>lexical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.9565217391304348);'>syntactic</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>operationalizing</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>components</span> <span style=''>of</span> <span style=''>politeness</span> <span style=''>theory</span> <span style=''>such</span> <span style=''>as</span> <span style=''>indirection</span> <span style=''>deference</span> <span style=''>impersonalization</span> <span style=''>and</span> <span style=''>modality</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>achieves</span> <span style=''>close</span> <span style=''>to</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.345646437994723);'>effective</span> <span style=''>across</span> <span style=''>domains</span> <span style=''>We</span> <span style=''>use</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>politeness</span> <span style=''>and</span> <span style=''>social</span> <span style=''>power</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>polite</span> <span style='background-color:rgba(0, 255, 0, 0.7391304347826088);' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>MCMC</span> <span style=''>Methods</span> <span style=''>for</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>gradient</span> <span style=''>MCMC</span> <span style=''>(SG</span> <span style=''>MCMC)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>proven</span> <span style=''>useful</span> <span style=''>in</span> <span style=''>scaling</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>to</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>under</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>of</span> <span style=''>iid</span> <span style=''>data</span> <span style=''>We</span> <span style=''>instead</span> <span style=''>develop</span> <span style=''>an</span> <span style=''>SG</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>hidden</span> <span style=''>Markov</span> <span style=''>models</span> <span style=''>(HMMs)</span> <span style=''>for</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependent</span> <span style=''>data</span> <span style=''>There</span> <span style=''>are</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>to</span> <span style=''>applying</span> <span style=''>SG</span> <span style=''>MCMC</span> <span style=''>in</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>The</span> <span style=''>latent</span> <span style=''>discrete</span> <span style=''>states</span> <span style=''>and</span> <span style=''>needing</span> <span style=''>to</span> <span style=''>break</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>when</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minibatches</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>HMM</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>harnesses</span> <span style=''>the</span> <span style=''>inherent</span> <span style=''>memory</span> <span style=''>decay</span> <span style=''>of</span> <span style=''>the</span> <span style=''>process</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>synthetic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>and</span> <span style=''>an</span> <span style=''>ion</span> <span style=''>channel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recording</span> <span style=''>d ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>General</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style='background-color:rgba(255, 0, 0, 0.46405228758169936);'>Graphical</span> <span style=''>Models</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.4653465346534653);'>Predictive</span> <span style=''>Belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <span style=''>and</span> <span style=''>Hilbert</span> <span style=''>Space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Embeddings</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>general</span> <span style=''>latent</span> <span style=''>variable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.46405228758169936);'>graphical</span> <span style=''>models</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4653465346534653);'>predictive</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.44800000000000006);'>representation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instrumental</span> <span style=''>variable</span> <span style='background-color:rgba(255, 0, 0, 0.5793991416309012);'>regression</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.6470588235294118);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embeddings</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3440514469453376);'>distributions</span> <span style=''>Under</span> <span style=''>this</span> <span style=''>new</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>first</span> <span style=''>convert</span> <span style=''>latent</span> <span style=''>variable</span> <span style='background-color:rgba(255, 0, 0, 0.46405228758169936);'>graphical</span> <span style=''>models</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>junction</span> <span style=''>trees</span> <span style=''>and</span> <span style=''>then</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>hard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>into</span> <span style=''>a</span> <span style=''>pipeline</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>whose</span> <span style=''>results</span> <span style=''>will</span> <span style=''>then</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.4653465346534653);'>predictive</span> <span style=''>belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>over</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>junction</span> <span style=''>tree</span> <span style=''>during</span> <span style=''>the</span> <span style=''>actual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Accurate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimators</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Improving</span> <span style=''>Minwise</span> <span style=''>Hashing</span> <span style=''>and</span> <span style=''>b</span> <span style=''>Bit</span> <span style=''>Minwise</span> <span style=''>Hashing</span> <br/><br/><span style=''>Minwise</span> <span style=''>hashing</span> <span style=''>is</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>search</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>set</span> <span style=''>(eg</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>01</span> <span style=''>vector)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>Recently</span> <span style=''>b</span> <span style=''>bit</span> <span style=''>minwise</span> <span style=''>hashing</span> <span style=''>was</span> <span style=''>proposed</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>improves</span> <span style=''>upon</span> <span style=''>the</span> <span style=''>original</span> <span style=''>minwise</span> <span style=''>hashing</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>by</span> <span style=''>storing</span> <span style=''>only</span> <span style=''>the</span> <span style=''>lowest</span> <span style=''>b</span> <span style=''>bits</span> <span style=''>of</span> <span style=''>each</span> <span style=''>hashed</span> <span style=''>value</span> <span style=''>as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>using</span> <span style=''>64</span> <span style=''>bits</span> <span style=''>b</span> <span style=''>bit</span> <span style=''>hashing</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>which</span> <span style=''>mainly</span> <span style=''>concern</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>(eg</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resemblance</span> <span style=''>05)</span> <span style=''>However</span> <span style=''>there</span> <span style=''>are</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>which</span> <span style=''>not</span> <span style=''>just</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>matter</span> <span style=''>For</span> <span style=''>example</span> <span style=''>many</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>require</span> <span style=''>all</span> <span style=''>pairwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>and</span> <span style=''>it</span> <span style=''>is</span> <span style=''>exp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.23823212360761767)
# 	automatic (0.07258354293927416)
# 	knowledge (0.1282788357887172)
# 	segmentation (0.07402084081925979)
# 	architecture (0.09234638878907654)
# 	representation (0.13007545813869925)
# 	detection (0.12504491555874955)
# 	different (0.279195113187208)
# 	recognition (0.1333093783686669)
# 	convolutional (0.14624505928853754)
#
# Some Statistics words are:
# 	algorithms (0.2850768468021815)
# 	theoretical (0.15121467526028756)
# 	statistical (0.14972731779871096)
# 	variables (0.1383242439266237)
# 	estimation (0.16807139315815567)
# 	inference (0.1789786812097174)
# 	algorithm (0.38671294000991574)
# 	distribution (0.17997025285076848)
# 	dimensional (0.18591968269707487)
# 	regression (0.18244918195339613)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="435d540d-56a0-4e9c-b6af-4f1c6a11e58c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("435d540d-56a0-4e9c-b6af-4f1c6a11e58c")) {                    Plotly.newPlot(                        "435d540d-56a0-4e9c-b6af-4f1c6a11e58c",                        [{"x":["component","decomposition","separability","efficient","restricted","factorization","subtraction","magnitude","performing","kronecker","relaxation","demonstrated","applications","combining","denoising","computations","algorithm","leverages","corruptions","processing","corruption","intersection","sensitive","effectiveness","introduce","significantly","comparison","dictionary","decomposable","expensive","additionally","structure","background","principal","statistical","difficulty","significant","conventional","information","components","movielens","transition","behaviors","important","recommendation","contextual","successfully","independently","experimental","historical","recurrent","sequences","situations","assumption","sequential","improvements","intervals","integrating","verification","application","withdrawn","selection","performance","following","classification","considering","technique","techniques","consensus","probability","determining","individual","iterative","presented","similarity","associated","reduction","determine","considered","framework","uncoupled","algorithms","eigenvalues","clustering","dimension","dimensional","encourages","evaluated","coefficients","estimation","experiences","successful","distributed","viewpoints","computational","exploitation","recommend","variability","diversity","uncertainty","conditional","classifier","predicted","estimator","targeting","preference","posterior","outperformed","providers","efficiently","efficiency","forecasts","identifying","efficiencies","personalized","uncertainties","exploration","exceptional","diversified","categorical","frequencies","normalized","qualitative","coordinates","frequency","modification","comparing","interpretable","according","assignment","relations","empirical","theoretical","character","proportions","displaying","distributions","languages","translations","different","applicable","categories","linguistically","graphical","variation","meaningful","incorporate","reservoir","robustness","challenging","correlation","balancing","mahalanobis","regularized","computationally","adaptability","unbounded","optimization","sacrificing","obtaining","foreground","dimensions","proximity","especially","furthermore","representation","exhibiting","appearance","demonstrate","representations","implementation","convergence","initialization","approaches","pollination","preserving","observers","evaluation","perception","investigate","quantitative","enhancement","standpoint","questions","answering","embeddings","descriptions","exploring","segmentation","generation","available","published","intermediate","detection","extensions","systematically","projection","decidability","expressed","knowledge","relationships","particular","conceptual","restricting","definitions","formalisms","semantics","conjunctive","operational","polynomial","homomorphism","decidable","hierarchy","existential","including","constraints","condition","operation","reasoning","complexity","realistic","continual","effective","stationary","unexplored","capabilities","continuous","architecture","extensive","considerable","difficult","capability","minibatch","extremely","normalization","describes","industrial","illustrates","constrained","constraint","precision","specification","intelligence","terminological","communicating","evolution","universally","technical","variables","artificial","foundation","configuration","programming","differentiated","convoluti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	asynchronously
# 	covariates
# 	borrowing
# 	sociology
# 	heteroscedasticity
# 	thickness
# 	inverting
# 	nomination
# 	heckerman
# 	revolutionize
# 	acceptancerejection
# 	parametrically
# 	covariances
# 	blockmodel
# 	transports
# 	newsvendor
# 	backfitting
# 	hoeffdings
# 	boundedness
# 	nonparanormal
# Some words which never appear in Statistics papers:
# 	withdrawn
# 	pollination
# 	observers
# 	decidability
# 	formalisms
# 	homomorphism
# 	decidable
# 	existential
# 	terminological
# 	qualified
# 	objectness
# 	morphology
# 	administration
# 	objection
# 	disjointness
# 	possibilistic
# 	discourse
# 	collocations
# 	collocation
# 	neuromuscular

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.085562652349656e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
